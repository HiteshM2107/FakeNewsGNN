# %% [markdown]
# # Fake News Detection with Graph Neural Networks
# ## Project Overview
#
# This project explores the use of **Graph Neural Networks (GNNs)** for detecting fake news articles. Traditional text-classification models treat each article independently, but misinformation often follows shared patterns, topics, and stylistic cues that relate articles to one another. To capture these relationships, this work constructs a **similarity-based graph** where each node represents a news article and edges represent semantic similarity derived from sentence embeddings.
#
# ### Key Components of the Project
#
# 1. **Text Preprocessing & Embedding Generation**
#    - Real and fake articles from the *FakeNewsNet (PolitiFact subset)* are cleaned and merged into a standardized dataset.
#    - Each article is encoded into a dense semantic vector using **Sentence Transformers (MiniLM)**.
#
# 2. **Graph Construction**
#    - Pairwise cosine similarity is computed between article embeddings.
#    - Articles exceeding a similarity threshold are connected, forming a graph where edges capture contextual and semantic relationships.
#
# 3. **PyTorch Geometric (PyG) Representation**
#    - The similarity graph is converted into a PyG `Data` object containing:
#      - `x` → node features (embeddings)
#      - `edge_index` → graph connections
#      - `y` → real/fake labels
#    - This unified representation is used to train GNN models.
#
# 4. **Baseline Models**
#    - Machine learning classifiers (Logistic Regression, SVM, Random Forest, Gradient Boosting) are trained directly on the MiniLM embeddings.
#    - These serve as reference points to evaluate how much relational information helps.
#
# 5. **GNN Modeling**
#    - Three GNN architectures are trained and evaluated:
#      - **GCN** (Graph Convolutional Network)
#      - **GraphSAGE** (Sampling-based aggregation)
#      - **GAT** (Graph Attention Network)
#    - Multiple random seeds ensure robustness and reliability.
#
# 6. **Embedding Visualization**
#    - The hidden node embeddings learned by GNNs are projected into 2D using **t-SNE**.
#    - These visualizations reveal how effectively each model separates real and fake news in latent space.
#
# 7. **Performance Comparison**
#    - Metrics (accuracy, F1-score), training curves, and t-SNE plots are aggregated.
#    - Results consistently show that **GNN models outperform traditional baselines**, with **GAT delivering the strongest performance** due to its attention mechanism.
#
#
#
# ## What This Notebook Covers
#
# This notebook walks through the end-to-end workflow of the Fake News GNN project:
#
# - Loading and understanding the dataset
# - Building or loading the similarity graph
# - Converting the graph into PyTorch Geometric format
# - Training baseline machine learning models
# - Training GNN models (GCN, GraphSAGE, GAT)
# - Running t-SNE to visualize node embeddings
# - Comparing all models using consistent metrics
#
# Overall, this notebook serves both as a **reproducible experiment** and a **complete explanation of the Fake News GNN pipeline**.

# %% [markdown]
# ## 1. Environment Setup

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: torch in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (2.2.2)
# Collecting torch-geometric (from -r ../requirements.txt (line 2))
#   Using cached torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: pandas in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: numpy in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (2.3.4)
# Requirement already satisfied: scikit-learn in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: networkx in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (3.5)
# Requirement already satisfied: matplotlib in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (3.10.7)
# Requirement already satisfied: transformers in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 8)) (4.57.1)
# Requirement already satisfied: tqdm in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: filelock in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (2025.10.0)
# Collecting aiohttp (from torch-geometric->-r ../requirements.txt (line 2))
#   Downloading aiohttp-3.13.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: psutil>=5.8.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch-geometric->-r ../requirements.txt (line 2)) (7.1.3)
# Requirement already satisfied: pyparsing in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch-geometric->-r ../requirements.txt (line 2)) (3.2.5)
# Requirement already satisfied: requests in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch-geometric->-r ../requirements.txt (line 2)) (2.32.5)
# Collecting xxhash (from torch-geometric->-r ../requirements.txt (line 2))
#   Downloading xxhash-3.6.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from pandas->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from pandas->-r ../requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from pandas->-r ../requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (12.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 8)) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 8)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 8)) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r ../requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 3)) (1.17.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Downloading frozenlist-1.8.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Downloading multidict-6.7.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Downloading propcache-0.4.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->torch-geometric->-r ../requirements.txt (line 2))
#   Downloading yarl-1.22.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: idna>=2.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->torch-geometric->-r ../requirements.txt (line 2)) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from jinja2->torch->-r ../requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->torch-geometric->-r ../requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->torch-geometric->-r ../requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->torch-geometric->-r ../requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sympy->torch->-r ../requirements.txt (line 1)) (1.3.0)
# Using cached torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
# Downloading aiohttp-3.13.2-cp312-cp312-macosx_10_13_x86_64.whl (492 kB)
# Downloading multidict-6.7.0-cp312-cp312-macosx_10_13_x86_64.whl (45 kB)
# Downloading yarl-1.22.0-cp312-cp312-macosx_10_13_x86_64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-macosx_10_13_x86_64.whl (50 kB)
# Downloading propcache-0.4.1-cp312-cp312-macosx_10_13_x86_64.whl (46 kB)
# Downloading xxhash-3.6.0-cp312-cp312-macosx_10_13_x86_64.whl (32 kB)
# Installing collected packages: xxhash, propcache, multidict, frozenlist, attrs, aiohappyeyeballs, yarl, aiosignal, aiohttp, torch-geometric
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [torch-geometric] [torch-geometric]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 attrs-25.4.0 frozenlist-1.8.0 multidict-6.7.0 propcache-0.4.1 torch-geometric-2.7.0 xxhash-3.6.0 yarl-1.22.0

# %% [markdown]
# ## 2. Run Data Preprocessing

# %%
# !python ../src/preprocess.py
# Out:
# Saved data/processed/posts.csv
# Total posts: 1056

# %% [markdown]
# ## 3. Build Graph

# %%
# This cell is optional since I already have the virtual environment set and all the dependencies installed
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Using cached sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --force-reinstall "numpy<2"
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 1.9 MB/s  0:00:10m0:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python ../src/build_graph.py
# Out:
# Loading posts...
# Preparing content column...
# Updated posts.csv saved with new 'content' column.
# Loading embedding model (MiniLM)...
# Generating embeddings...
# Batches: 100%|██████████████████████████████████| 33/33 [00:16<00:00,  1.95it/s]
# Computing cosine similarity matrix...
# Building similarity graph...
# Saving graph to data/processed/graph.pkl
#
# Graph saved successfully!
# Total nodes: 1056
# Total edges: 634

# %% [markdown]
# ## 4. Train Baseline Models

# %%
# !python ../src/train_baselines.py
# Out:
# LogisticRegression: Accuracy=0.7925, F1=0.7273
# SVM: Accuracy=0.8302, F1=0.7970

# %% [markdown]
# ## 5. Train GNN Models

# %%
# !python ../src/train_gnn.py --model gcn
# Out:
# --- Training GCN ---
# Seed 42 — Val: 0.8671, Test: 0.8113, Time: 0.93s
# Seed 43 — Val: 0.8861, Test: 0.8491, Time: 0.88s
# Seed 44 — Val: 0.8544, Test: 0.8742, Time: 0.83s
# Seed 45 — Val: 0.8861, Test: 0.8428, Time: 0.86s
# Seed 46 — Val: 0.8608, Test: 0.8994, Time: 0.81s
#
# --- Training GraphSAGE ---
# Seed 42 — Val: 0.8734, Test: 0.8491, Time: 1.19s
# Seed 43 — Val: 0.8924, Test: 0.8553, Time: 1.16s
# Seed 44 — Val: 0.8481, Test: 0.8931, Time: 1.21s
# Seed 45 — Val: 0.8797, Test: 0.8365, Time: 1.22s
# Seed 46 — Val: 0.8671, Test: 0.8994, Time: 1.22s
#
# --- Training GAT ---
# Seed 42 — Val: 0.8797, Test: 0.8365, Time: 1.92s
# Seed 43 — Val: 0.8861, Test: 0.8742, Time: 1.99s
# Seed 44 — Val: 0.8671, Test: 0.8868, Time: 2.02s
# Seed 45 — Val: 0.8987, Test: 0.8616, Time: 1.96s
# Seed 46 — Val: 0.8608, Test: 0.9057, Time: 1.98s
#
#  Training complete. Results and plots saved to results/

# %%
# !python ../src/train_gnn.py --model sage
# Out:
# --- Training GCN ---
# Seed 42 — Val: 0.8671, Test: 0.8113, Time: 0.83s
# Seed 43 — Val: 0.8861, Test: 0.8491, Time: 0.79s
# Seed 44 — Val: 0.8544, Test: 0.8742, Time: 0.83s
# Seed 45 — Val: 0.8861, Test: 0.8428, Time: 0.86s
# Seed 46 — Val: 0.8608, Test: 0.8994, Time: 0.82s
#
# --- Training GraphSAGE ---
# Seed 42 — Val: 0.8734, Test: 0.8491, Time: 1.25s
# Seed 43 — Val: 0.8924, Test: 0.8553, Time: 1.28s
# Seed 44 — Val: 0.8481, Test: 0.8931, Time: 1.20s
# Seed 45 — Val: 0.8797, Test: 0.8365, Time: 1.19s
# Seed 46 — Val: 0.8671, Test: 0.8994, Time: 1.22s
#
# --- Training GAT ---
# Seed 42 — Val: 0.8797, Test: 0.8365, Time: 1.95s
# Seed 43 — Val: 0.8861, Test: 0.8742, Time: 1.96s
# Seed 44 — Val: 0.8671, Test: 0.8868, Time: 1.93s
# Seed 45 — Val: 0.8987, Test: 0.8616, Time: 1.94s
# Seed 46 — Val: 0.8608, Test: 0.9057, Time: 1.97s
#
#  Training complete. Results and plots saved to results/

# %%
# !python ../src/train_gnn.py --model gat
# Out:
# --- Training GCN ---
# Seed 42 — Val: 0.8671, Test: 0.8113, Time: 0.89s
# Seed 43 — Val: 0.8861, Test: 0.8491, Time: 0.85s
# Seed 44 — Val: 0.8544, Test: 0.8742, Time: 0.87s
# Seed 45 — Val: 0.8861, Test: 0.8428, Time: 0.86s
# Seed 46 — Val: 0.8608, Test: 0.8994, Time: 0.89s
#
# --- Training GraphSAGE ---
# Seed 42 — Val: 0.8734, Test: 0.8491, Time: 1.34s
# Seed 43 — Val: 0.8924, Test: 0.8553, Time: 1.23s
# Seed 44 — Val: 0.8481, Test: 0.8931, Time: 1.25s
# Seed 45 — Val: 0.8797, Test: 0.8365, Time: 1.26s
# Seed 46 — Val: 0.8671, Test: 0.8994, Time: 1.36s
#
# --- Training GAT ---
# Seed 42 — Val: 0.8797, Test: 0.8365, Time: 1.91s
# Seed 43 — Val: 0.8861, Test: 0.8742, Time: 1.99s
# Seed 44 — Val: 0.8671, Test: 0.8868, Time: 1.96s
# Seed 45 — Val: 0.8987, Test: 0.8616, Time: 1.94s
# Seed 46 — Val: 0.8608, Test: 0.9057, Time: 1.97s
#
#  Training complete. Results and plots saved to results/

# %% [markdown]
# ## 6. Visualize Embeddings

# %%
# For GCN
# !python ../src/tsne_embeddings.py --model GCN
# Out:
# === Running t-SNE for model: GCN ===
# Loaded graph with 1056 nodes, 1268 edges.
# Node feature dim = 384, num_classes = 2
# Using checkpoint: checkpoints/GCN_seed42.pt
# Detected hidden_dim = 16 from 'conv1.lin.weight'
# Running t-SNE...
# /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages/threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# Saved t-SNE plot to: results/GCN_tsne.png
# === Done ===

# %%
# For GraphSAGE
# !python ../src/tsne_embeddings.py --model GraphSAGE
# Out:
# === Running t-SNE for model: GraphSAGE ===
# Loaded graph with 1056 nodes, 1268 edges.
# Node feature dim = 384, num_classes = 2
# Using checkpoint: checkpoints/GraphSAGE_seed42.pt
# Detected hidden_dim = 16 from 'conv1.lin_l.weight'
# Running t-SNE...
# /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages/threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# Saved t-SNE plot to: results/GraphSAGE_tsne.png
# === Done ===

# %%
# For GAT
# !python ../src/tsne_embeddings.py --model GAT
# Out:
# === Running t-SNE for model: GAT ===
# Loaded graph with 1056 nodes, 1268 edges.
# Node feature dim = 384, num_classes = 2
# Using checkpoint: checkpoints/GAT_seed42.pt
# Detected GAT hidden_dim = 16 from 'conv1.att_src'
# Running t-SNE...
# /Users/hiteshmalhotra/Desktop/MSU academics/Fall25/CSE 841 Artificial Intelligence/Project/venv/lib/python3.12/site-packages/threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# Saved t-SNE plot to: results/GAT_tsne.png
# === Done ===

# %% [markdown]
# ## 7. Load and Compare Results

# %%
import json, pandas as pd, glob

# Load baselines
with open('results/baselines.json') as f:
    baselines = json.load(f)

# Load all GNN report json files
gnn_files = glob.glob("results/*_report.json")

gnn_reports = []
for path in gnn_files:
    with open(path) as f:
        report = json.load(f)
        report["model"] = os.path.basename(path).replace("_report.json", "")
        gnn_reports.append(report)

baselines_df = pd.DataFrame(baselines)
gnn_df = pd.DataFrame(gnn_reports)

baselines_df, gnn_df
# Out:
# (          LogisticRegression     SVM
#  accuracy              0.7925  0.8302
#  f1_score              0.7273  0.7970,
#                                                      0  \
#  0   {'precision': 0.9029126213592233, 'recall': 0....
#  1   {'precision': 0.9090909090909091, 'recall': 0....
#  2   {'precision': 0.9117647058823529, 'recall': 0....
#  3   {'precision': 0.8165137614678899, 'recall': 0....
#  4   {'precision': 0.865979381443299, 'recall': 0.8...
#  5   {'precision': 0.7981651376146789, 'recall': 0....
#  6   {'precision': 0.8556701030927835, 'recall': 0....
#  7   {'precision': 0.85, 'recall': 0.89473684210526...
#  8   {'precision': 0.8476190476190476, 'recall': 0....
#  9   {'precision': 0.9150943396226415, 'recall': 0....
#  10  {'precision': 0.9065420560747663, 'recall': 0....
#  11  {'precision': 0.9142857142857143, 'recall': 0....
#  12  {'precision': 0.9186046511627907, 'recall': 0....
#  13  {'precision': 0.9294117647058824, 'recall': 0....
#  14  {'precision': 0.9130434782608695, 'recall': 0....
#
#                                                      1  accuracy  \
#  0   {'precision': 0.8571428571428571, 'recall': 0....  0.886792
#  1   {'precision': 0.8166666666666667, 'recall': 0....  0.874214
#  2   {'precision': 0.8596491228070176, 'recall': 0....  0.893082
#  3   {'precision': 0.88, 'recall': 0.6875, 'f1-scor...  0.836478
#  4   {'precision': 0.8225806451612904, 'recall': 0....  0.849057
#  5   {'precision': 0.84, 'recall': 0.65625, 'f1-sco...  0.811321
#  6   {'precision': 0.8064516129032258, 'recall': 0....  0.836478
#  7   {'precision': 0.8305084745762712, 'recall': 0....  0.842767
#  8   {'precision': 0.8888888888888888, 'recall': 0....  0.861635
#  9   {'precision': 0.8867924528301887, 'recall': 0....  0.905660
#  10  {'precision': 0.8846153846153846, 'recall': 0....  0.899371
#  11  {'precision': 0.8703703703703703, 'recall': 0....  0.899371
#  12  {'precision': 0.7671232876712328, 'recall': 0....  0.849057
#  13  {'precision': 0.7702702702702703, 'recall': 0....  0.855346
#  14  {'precision': 0.8208955223880597, 'recall': 0....  0.874214
#
#                                              macro avg  \
#  0   {'precision': 0.8800277392510403, 'recall': 0....
#  1   {'precision': 0.8628787878787878, 'recall': 0....
#  2   {'precision': 0.8857069143446852, 'recall': 0....
#  3   {'precision': 0.848256880733945, 'recall': 0.8...
#  4   {'precision': 0.8442800133022947, 'recall': 0....
#  5   {'precision': 0.8190825688073394, 'recall': 0....
#  6   {'precision': 0.8310608579980046, 'recall': 0....
#  7   {'precision': 0.8402542372881356, 'recall': 0....
#  8   {'precision': 0.8682539682539683, 'recall': 0....
#  9   {'precision': 0.9009433962264151, 'recall': 0....
#  10  {'precision': 0.8955787203450755, 'recall': 0....
#  11  {'precision': 0.8923280423280423, 'recall': 0....
#  12  {'precision': 0.8428639694170117, 'recall': 0....
#  13  {'precision': 0.8498410174880764, 'recall': 0....
#  14  {'precision': 0.8669695003244646, 'recall': 0....
#
#                                           weighted avg             model
#  0   {'precision': 0.8862167325255802, 'recall': 0....        GAT_seed44
#  1   {'precision': 0.8753764055650848, 'recall': 0....        GCN_seed44
#  2   {'precision': 0.8927539900435514, 'recall': 0....  GraphSAGE_seed44
#  3   {'precision': 0.8420679706883618, 'recall': 0....        GAT_seed42
#  4   {'precision': 0.8485107077197233, 'recall': 0....  GraphSAGE_seed42
#  5   {'precision': 0.8150043275056258, 'recall': 0....        GCN_seed42
#  6   {'precision': 0.8358588869158546, 'recall': 0....  GraphSAGE_seed45
#  7   {'precision': 0.8421543545464236, 'recall': 0....        GCN_seed45
#  8   {'precision': 0.864230807627034, 'recall': 0.8...        GAT_seed45
#  9   {'precision': 0.905126379494482, 'recall': 0.9...        GAT_seed46
#  10  {'precision': 0.8988194548060533, 'recall': 0....        GCN_seed46
#  11  {'precision': 0.8988186749193039, 'recall': 0....  GraphSAGE_seed46
#  12  {'precision': 0.8585837335529282, 'recall': 0....        GCN_seed43
#  13  {'precision': 0.866355700872904, 'recall': 0.8...  GraphSAGE_seed43
#  14  {'precision': 0.8765320240471147, 'recall': 0....        GAT_seed43  )
